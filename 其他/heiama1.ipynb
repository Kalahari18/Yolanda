# %% [markdown]
# # 1.操作系统（控制硬件，支持软件）
# ## Linux操作系统
# # 虚拟机软件（搭载虚拟机） vmware软件
# # linux命令
# ## 3.ubuntu操作系统
# windows盘符结构
# ubuntu文件概念，只有一个根目录
# ## 4.linux内核及发行版
# linux发行版本  内核及各种软件（内核没变）
# ## 5.linux命令
# 查看目录命令 ls tree pwd clear ctrl+shift++ Ctrl+-
# 切换目录 cd cd ~  cd .. cd . cd -
# 绝对命令与相对命令
# 创建，删除
# touch mkdir rm rmdir
# 终端命令选择  commad [-options][parameter] []代表可选
# 查看命令帮助方式 --help man
# ls -l h -a
# mkdir -p
# rm -i -r -f
# cp -i -r -v
# mv -i -v
# # 2.文件操作
# ## 1.重定向命令
# >覆盖  >> 追加
# ## 2.查看文件内容命令
# cat(小型文件) more（f向下翻页 b向上翻译 enter q 退出） 查看大型文件  |
# ## 3.链接命令（相当于快捷键）
# ln -s（使用绝对路径）
# ## 4.查找文件内容命令
# grep -v 不包含 -n 行号 -i忽略大小写 ^指定开头&指定结尾 .任意字符
# ## 5.查找文件
# find -name 通配符 *（0或者1任意字符） ？（1个字符）
# ## 6.压缩与解压缩命令
# .gz .bz2
# tar  -c -v(显示详细信息) -f（指定文件名称） -z（gz） -j（bz2） -x（解压） -C（指定解压目录）
# ## 7.文件权限命令
# 文件类型和权限 用户名 用户组 文件大小 文件修改时间  文件名
# 文件权限说明
# 文件类型 -普通文件 d表示文件夹 文件所有者用户权限，文件用户组权限 其他用户的权限
# r可读 w可写  x可执行 -没有权限
# 文件权限修改  chmod u/g/o/a+/-/=rwx字母法
# u 表示该文件所有者 g用户组 o表示其他用户 a 所有用户  +增加权限 -撤销权限 =设置权限
# r可读 w 可写 x可执行 -无任何权限
# chmod 数字法 r 4 w 2 x 1 -0
# ## 10.获取管理员权限的命令
# sudo -s sudo
# whomi WHO  EXIT
# WHICH
# 修改密码 passwd
# SHUtdown -h now
# ## 9.远程登录，远程拷贝命令
# ssh命令 openssh-server
# ssh user@host
# scp 给予ssh进行远程文件拷贝命令
# scp 本地文件 远程usr@host：路径
# scp 远程user@host ：路径 当前路径
# -r 目录
# filezilla软件 可视化上传与下载
# ## 12.软件安装
# 离线安装 deb文件格式安装 dpkg -i
# 在线安装 apt-get
# 更改镜像源
# ## 13.软件卸载
# sudo dpkg -r 安装包名
# sudo apt-get remove
# ## 14.vim介绍
#
# 命令模式 编辑模式 末行模式
# i 编辑模式
# ：末行模式
# esc 命令行模式
# w wq x q!
# 常用命令
# 命令模式  yy 复制光标所在行  p粘贴   dd删除/剪辑当前行  V按行选中
# u 撤销 ctr+r 反撤销 G回到最后一行  gg 回到第一行  数字+G 回到指定行
# ：/搜索指定内容 ：%s/要替换的内容/替换后的内容/g 全局替换
# .重复上一次操作  >> 往右缩进  <<往左缩进
# ：开始行数，结束行数/要替换的内容/替换后的内容 局部替换
# shift+6 回到当前行的行首
# shift+4 回到当前行的行末
# ctr+f 下一屏
# ctr+b 上一屏
# # 进程与线程
# ## 多任务的介绍
# 多任务(利用cpu资源，提高执行效率)
# 并发（交替执行多个任务，单核cpu）
# 并行（真正同时一起执行）
# ## 进程的介绍
# 在python使用多进程执行多任务
# 多进程的作用
# ## 多进程完成多任务
# 导入进程包
# 创建进程对象 target
# 启动进程
